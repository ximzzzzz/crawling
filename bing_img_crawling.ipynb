# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

import json
import os
import argparse

import requests
import urllib
import urllib3
from urllib3.exceptions import InsecureRequestWarning

import datetime
import time
import sys

urllib3.disable_warnings(InsecureRequestWarning)

# %%
def download_bing_staticimages(search_url,dirs):
    options = webdriver.ChromeOptions()
    options.add_argument('--no-sandbox')
    #options.add_argument('--headless')

    try:
        browser = webdriver.Chrome(chromedriver, options=options)
    except Exception as e:
        print(f'No found chromedriver in this environment.')
        print(f'Install on your machine. exception: {e}')
        sys.exit()

    browser.set_window_size(1280, 1024)
    browser.get(search_url)
    time.sleep(1)


    element = browser.find_element_by_tag_name('body')

    # Scroll down
    for i in range(50):
        element.send_keys(Keys.PAGE_DOWN)
        time.sleep(0.3)

    try:
        browser.find_element_by_id('smb').click()
        for i in range(50):
            element.send_keys(Keys.PAGE_DOWN)
            time.sleep(0.3)
    except:
        for i in range(10):
            element.send_keys(Keys.PAGE_DOWN)
            time.sleep(0.3)

    print(f'Reached end of page.')
    time.sleep(0.5)



    try:
#         browser.find_element_by_xpath('//*[@id="_sau_imageTab"]/div[2]/div[8]/a').send_keys(Keys.ENTER)

        # Scroll down 2
        for i in range(50):
            element.send_keys(Keys.PAGE_DOWN)
            time.sleep(0.3)

        try:
            browser.find_element_by_id('smb').click()
            for i in range(50):
                element.send_keys(Keys.PAGE_DOWN)
                time.sleep(0.3)
        except:
            for i in range(10):
                element.send_keys(Keys.PAGE_DOWN)
                time.sleep(0.3)

    except Exception as e:
        print('Error at {} for {}'.format( dirs.split('/')[-1], e))

    page_source = browser.page_source 

    soup = BeautifulSoup(page_source, 'lxml')
    images = soup.find_all('img')

    urls = []
    for image in images:
        try:
            url = image['data-src']
            if not url.find('https://'):
                urls.append(url)
        except:
            try:
                url = image['src']
                if not url.find('https://'):
                    urls.append(image['src'])
            except Exception as e:
                print(f'No found image sources.')
                print(e)

    count = 0
    if urls:
        for url in urls[2:-1]: # 0,1 은 naver 마크랑 배너 -1은 x마크
            try:
                res = requests.get(url, verify=False, stream=True)
                rawdata = res.raw.read()
                with open(os.path.join(dirs, 'img_bing_' + str(count) + '.jpg'), 'wb') as f:
                    f.write(rawdata)
                    count += 1
            except Exception as e:
                print('Failed to write rawdata.')
                print(e)

    browser.close()
    return count


def crawler(keywords):
    
    search_url = base_url
    keywords_list = [x.strip() for x in keywords.split(',')]
    for idx,  keyword in enumerate(keywords_list):
        if idx ==0:
            search_url = search_url+keyword
        else :
            search_url = search_url+ '%20' + keyword
        
#     search_url = search_url + tail_url
    
    dirs = 'images/{}'.format(keywords_list[0]) 
    if not os.path.exists(dirs):
        os.mkdir(dirs)
   
    t0 = time.time()
    count = download_bing_staticimages(search_url, dirs)
    t1 = time.time()

    total_time = t1 - t0
#     print(f'\n')
    print(f'Download completed. [Successful count = {count}].')
    print(f'Total time is {str(total_time)} seconds.')

# %%
import pandas as pd
from tqdm import tqdm_notebook as tqdm

# %%
base_url = 'https://www.bing.com/images/search?q='
# search_url = base_url + query
chromedriver = '../PHR/chromedriver.exe'
crawling_words = pd.read_excel('식사일기_서비스_이미지_크롤링.xlsx', sheet_name='데이터 수집필요', header=None, names=['재료', 2,3,4] )

# %%
for food in tqdm(crawling_words['재료']):
    crawler(food)
# Out:
# C:\Users\NB-0242\Anaconda3\envs\ximz\lib\site-packages\ipykernel_launcher.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """Entry point for launching an IPython kernel.
# HBox(children=(FloatProgress(value=0.0, max=557.0), HTML(value='')))
# Reached end of page.
# Download completed. [Successful count = 935].
# Total time is 82.33774876594543 seconds.
# Reached end of page.
# Download completed. [Successful count = 892].
# Total time is 80.73802995681763 seconds.
# Reached end of page.
# Download completed. [Successful count = 775].
# Total time is 82.03256893157959 seconds.
# Reached end of page.
# Download completed. [Successful count = 41].
# Total time is 52.58708310127258 seconds.
# Reached end of page.
# Download completed. [Successful count = 658].
# Total time is 72.59680700302124 seconds.
# Reached end of page.
# Download completed. [Successful count = 854].
# Total time is 90.62997794151306 seconds.
# Reached end of page.
# Download completed. [Successful count = 268].
# Total time is 69.77734923362732 seconds.
# Reached end of page.
# Download completed. [Successful count = 844].
# Total time is 96.29655146598816 seconds.
# Reached end of page.
# Download completed. [Successful count = 865].
# Total time is 86.1385850906372 seconds.
# Reached end of page.
# Download completed. [Successful count = 859].
# Total time is 107.16733241081238 seconds.
# Reached end of page.
# Download completed. [Successful count = 824].
# Total time is 96.1268663406372 seconds.
# Reached end of page.
# Download completed. [Successful count = 682].
# Total time is 90.98857975006104 seconds.
# Reached end of page.
# Download completed. [Successful count = 816].
# Total time is 99.18233847618103 seconds.
# Reached end of page.
# Download completed. [Successful count = 765].
# Total time is 76.73445510864258 seconds.
# Reached end of page.
# Download completed. [Successful count = 820].
# Total time is 102.0520248413086 seconds.
# Reached end of page.
# Download completed. [Successful count = 717].
# Total time is 69.08256006240845 seconds.
# Reached end of page.
# Download completed. [Successful count = 901].
# Total time is 80.66921377182007 seconds.
# Reached end of page.
# Download completed. [Successful count = 690].
# Total time is 93.05520462989807 seconds.
# Reached end of page.
# Download completed. [Successful count = 798].
# Total time is 77.7270929813385 seconds.
# Reached end of page.
# Download completed. [Successful count = 753].
# Total time is 129.61946630477905 seconds.
# Reached end of page.
# Download completed. [Successful count = 817].
# Total time is 78.2806043624878 seconds.
# Reached end of page.
# Download completed. [Successful count = 845].
# Total time is 93.04911351203918 seconds.
# Reached end of page.
# Download completed. [Successful count = 692].
# Total time is 76.2170672416687 seconds.
# Reached end of page.
# Download completed. [Successful count = 684].
# Total time is 90.52884864807129 seconds.
# Reached end of page.
# Download completed. [Successful count = 853].
# Total time is 118.48523259162903 seconds.
# Reached end of page.
# Download completed. [Successful count = 827].
# Total time is 143.35353922843933 seconds.
# Reached end of page.
# Download completed. [Successful count = 700].
# Total time is 110.56288409233093 seconds.
# Reached end of page.
# Download completed. [Successful count = 911].
# Total time is 90.61647272109985 seconds.
# Reached end of page.
# Download completed. [Successful count = 913].
# Total time is 100.40741920471191 seconds.
# Reached end of page.
# Download completed. [Successful count = 76].
# Total time is 61.8295738697052 seconds.
# Reached end of page.
# Download completed. [Successful count = 795].
# Total time is 72.44421410560608 seconds.
# Reached end of page.
# Download completed. [Successful count = 783].
# Total time is 83.24734210968018 seconds.
# Reached end of page.
# Download completed. [Successful count = 58].
# Total time is 59.136789083480835 seconds.
# Reached end of page.
# Download completed. [Successful count = 805].
# Total time is 168.0504834651947 seconds.
# Reached end of page.
# Download completed. [Successful count = 860].
# Total time is 129.78084588050842 seconds.
# Reached end of page.
# Download completed. [Successful count = 857].
# Total time is 82.88030052185059 seconds.
# Reached end of page.
# Download completed. [Successful count = 933].
# Total time is 128.85236263275146 seconds.
# Reached end of page.
# Download completed. [Successful count = 0].
# Total time is 51.36860227584839 seconds.
# Reached end of page.
# Download completed. [Successful count = 723].
# Total time is 86.61335730552673 seconds.
# Reached end of page.
# Download completed. [Successful count = 825].
# Total time is 102.07745099067688 seconds.
# Reached end of page.
# Download completed. [Successful count = 799].
# Total time is 137.92904949188232 seconds.
# Reached end of page.
# Download completed. [Successful count = 798].
# Total time is 97.89414691925049 seconds.
# Reached end of page.
# Download completed. [Successful count = 919].
# Total time is 101.93832206726074 seconds.
# Reached end of page.
# Download completed. [Successful count = 307].
# Total time is 103.85220575332642 seconds.
# Reached end of page.
# Download completed. [Successful count = 822].
# Total time is 98.11953783035278 seconds.
# Reached end of page.
# Download completed. [Successful count = 389].
# Total time is 67.19725131988525 seconds.
# Reached end of page.
# Download completed. [Successful count = 174].
# Total time is 56.892784118652344 seconds.
# Reached end of page.
# Download completed. [Successful count = 374].
# Total time is 63.7424955368042 seconds.
# Reached end of page.
# Download completed. [Successful count = 762].
# Total time is 79.23501777648926 seconds.
# Reached end of page.
# Download completed. [Successful count = 640].
# Total time is 70.66129755973816 seconds.
# Reached end of page.
# Download completed. [Successful count = 898].
# Total time is 117.03424882888794 seconds.
# Reached end of page.
# Download completed. [Successful count = 810].
# Total time is 85.3051073551178 seconds.
# Reached end of page.
# Download completed. [Successful count = 862].
# Total time is 72.14386487007141 seconds.
# Reached end of page.
# Download completed. [Successful count = 908].
# Total time is 104.94830775260925 seconds.
# Reached end of page.
# Download completed. [Successful count = 864].
# Total time is 80.72306156158447 seconds.
# Reached end of page.
# Download completed. [Successful count = 889].
# Total time is 84.28753638267517 seconds.
# Reached end of page.
# Download completed. [Successful count = 191].
# Total time is 64.55432367324829 seconds.
# Reached end of page.
# Download completed. [Successful count = 683].
# Total time is 73.47645306587219 seconds.
# Reached end of page.
# Download completed. [Successful count = 682].
# Total time is 81.1838390827179 seconds.
# Reached end of page.
# Download completed. [Successful count = 907].
# Total time is 87.99001121520996 seconds.
# Reached end of page.
# Download completed. [Successful count = 857].
# Total time is 88.9307610988617 seconds.
# Reached end of page.
# Download completed. [Successful count = 765].
# Total time is 76.81271600723267 seconds.
# Reached end of page.
# Download completed. [Successful count = 902].
# Total time is 83.75599551200867 seconds.
# Reached end of page.
# Download completed. [Successful count = 933].
# Total time is 77.14224171638489 seconds.
# Reached end of page.
# Download completed. [Successful count = 856].
# Total time is 81.04209303855896 seconds.
# Reached end of page.
# Download completed. [Successful count = 758].
# Total time is 80.95505690574646 seconds.
# Reached end of page.
# Download completed. [Successful count = 857].
# Total time is 90.65108060836792 seconds.
# Reached end of page.
# Download completed. [Successful count = 909].
# Total time is 85.260244846344 seconds.
# Reached end of page.
# Download completed. [Successful count = 0].
# Total time is 51.197473764419556 seconds.
# Reached end of page.
# Download completed. [Successful count = 876].
# Total time is 89.64513158798218 seconds.
# Reached end of page.
# Download completed. [Successful count = 889].
# Total time is 106.6975359916687 seconds.
# Reached end of page.
# Download completed. [Successful count = 931].
# Total time is 95.2701404094696 seconds.
# Reached end of page.
# Download completed. [Successful count = 907].
# Total time is 102.68858432769775 seconds.
# Reached end of page.
# Download completed. [Successful count = 883].
# Total time is 93.91877150535583 seconds.
# Reached end of page.
# Download completed. [Successful count = 919].
# Total time is 95.48533582687378 seconds.
# Reached end of page.
# Download completed. [Successful count = 884].
# Total time is 88.00515699386597 seconds.
# Reached end of page.
# Download completed. [Successful count = 702].
# Total time is 73.95118856430054 seconds.
# Reached end of page.
# Download completed. [Successful count = 866].
# Total time is 79.49829077720642 seconds.
# Reached end of page.
# Download completed. [Successful count = 74].
# Total time is 64.1846091747284 seconds.
# Reached end of page.
# Download completed. [Successful count = 769].
# Total time is 82.28219676017761 seconds.
# Reached end of page.
# Download completed. [Successful count = 775].
# Total time is 90.33584928512573 seconds.
# Reached end of page.
# Download completed. [Successful count = 890].
# Total time is 99.60356616973877 seconds.
# Reached end of page.
# Download completed. [Successful count = 851].
# Total time is 84.13907027244568 seconds.
# Reached end of page.
# Download completed. [Successful count = 845].
# Total time is 82.39659476280212 seconds.
# Reached end of page.
# Download completed. [Successful count = 914].
# Total time is 100.60838532447815 seconds.
# Reached end of page.
# Download completed. [Successful count = 682].
# Total time is 97.65976619720459 seconds.
# Reached end of page.
# Download completed. [Successful count = 869].
# Total time is 94.00808501243591 seconds.
# Reached end of page.
# Download completed. [Successful count = 746].
# Total time is 82.19347286224365 seconds.
# Reached end of page.
# Download completed. [Successful count = 928].
# Total time is 91.93668341636658 seconds.
# Reached end of page.
# Download completed. [Successful count = 847].
# Total time is 92.62437319755554 seconds.
# Reached end of page.
# Download completed. [Successful count = 804].
# Total time is 83.4337797164917 seconds.
# Reached end of page.
# Download completed. [Successful count = 708].
# Total time is 82.54502868652344 seconds.
# Reached end of page.
# Download completed. [Successful count = 739].
# Total time is 93.11094069480896 seconds.
# Reached end of page.
# Download completed. [Successful count = 779].
# Total time is 92.48416757583618 seconds.
# Reached end of page.
# Download completed. [Successful count = 837].
# Total time is 152.74043154716492 seconds.
# Reached end of page.
# Download completed. [Successful count = 742].
# Total time is 80.6812391281128 seconds.
# Reached end of page.
# Download completed. [Successful count = 898].
# Total time is 106.82126021385193 seconds.
# Reached end of page.
# Download completed. [Successful count = 823].
# Total time is 84.3005006313324 seconds.
# Reached end of page.
# Download completed. [Successful count = 0].
# Total time is 55.38589096069336 seconds.
# Reached end of page.
# Download completed. [Successful count = 825].
# Total time is 85.15437769889832 seconds.
# Reached end of page.
# Download completed. [Successful count = 848].
# Total time is 98.6076602935791 seconds.
# Reached end of page.
# Download completed. [Successful count = 836].
# Total time is 83.2353503704071 seconds.
# Reached end of page.
# Download completed. [Successful count = 739].
# Total time is 80.2321572303772 seconds.
# Reached end of page.
# Download completed. [Successful count = 0].
# Total time is 51.426437854766846 seconds.
# Reached end of page.
# Download completed. [Successful count = 669].
# Total time is 82.19536805152893 seconds.
# Reached end of page.
# Download completed. [Successful count = 773].
# Total time is 86.2233567237854 seconds.
# Reached end of page.
# Download completed. [Successful count = 897].
# Total time is 97.11622166633606 seconds.
# Reached end of page.
# Download completed. [Successful count = 477].
# Total time is 68.00708293914795 seconds.
# Reached end of page.
# Download completed. [Successful count = 848].
# Total time is 91.62822484970093 seconds.
# Reached end of page.
# Download completed. [Successful count = 932].
# Total time is 99.4975962638855 seconds.
# Reached end of page.
# Download completed. [Successful count = 677].
# Total time is 74.44257235527039 seconds.
# Reached end of page.
# Download completed. [Successful count = 853].
# Total time is 86.00920748710632 seconds.
# Reached end of page.
# Download completed. [Successful count = 897].
# Total time is 115.77032423019409 seconds.
# Reached end of page.
# Download completed. [Successful count = 873].
# Total time is 106.21302604675293 seconds.
# Reached end of page.
# Download completed. [Successful count = 21].
# Total time is 57.050456523895264 seconds.
# Reached end of page.
# Download completed. [Successful count = 845].
# Total time is 165.68652153015137 seconds.
# Reached end of page.
# Download completed. [Successful count = 825].
# Total time is 164.09798526763916 seconds.
# Reached end of page.
# Download completed. [Successful count = 738].
# Total time is 100.75218367576599 seconds.
# Reached end of page.
# Download completed. [Successful count = 861].
# Total time is 180.65589380264282 seconds.
# Reached end of page.
# Download completed. [Successful count = 827].
# Total time is 100.58682608604431 seconds.
# Reached end of page.
# Download completed. [Successful count = 824].
# Total time is 165.5780885219574 seconds.
# Reached end of page.
# Download completed. [Successful count = 850].
# Total time is 86.86346864700317 seconds.
# Reached end of page.
# Download completed. [Successful count = 906].
# Total time is 114.32518720626831 seconds.
# Reached end of page.
# Download completed. [Successful count = 812].
# Total time is 96.44452857971191 seconds.
# Reached end of page.
# Download completed. [Successful count = 716].
# Total time is 79.22484612464905 seconds.
# Reached end of page.
# Download completed. [Successful count = 0].
# Total time is 55.66510081291199 seconds.
# Reached end of page.
# Download completed. [Successful count = 346].
# Total time is 68.08292555809021 seconds.
# Reached end of page.
# Download completed. [Successful count = 866].
# Total time is 103.49316143989563 seconds.
# Reached end of page.
# Download completed. [Successful count = 829].
# Total time is 80.05685710906982 seconds.
# Reached end of page.
# Download completed. [Successful count = 937].
# Total time is 82.80350637435913 seconds.
# Reached end of page.
# Download completed. [Successful count = 861].
# Total time is 95.78130173683167 seconds.
# Reached end of page.
# Download completed. [Successful count = 935].
# Total time is 87.108069896698 seconds.
# Reached end of page.
# Download completed. [Successful count = 855].
# Total time is 96.78573441505432 seconds.
# Reached end of page.
# Download completed. [Successful count = 881].
# Total time is 89.98728895187378 seconds.
# Reached end of page.
# Download completed. [Successful count = 288].
# Total time is 72.61989116668701 seconds.
# Reached end of page.
# Download completed. [Successful count = 788].
# Total time is 74.7410728931427 seconds.
# Reached end of page.
# Download completed. [Successful count = 673].
# Total time is 87.35433316230774 seconds.
# Reached end of page.
# Download completed. [Successful count = 792].
# Total time is 87.23364543914795 seconds.
# Reached end of page.
# Download completed. [Successful count = 883].
# Total time is 87.4552845954895 seconds.
# Reached end of page.
# Download completed. [Successful count = 640].
# Total time is 78.9149100780487 seconds.
# Reached end of page.
# Download completed. [Successful count = 949].
# Total time is 85.16419053077698 seconds.
# Reached end of page.
# Download completed. [Successful count = 544].
# Total time is 83.9557511806488 seconds.
# Reached end of page.
# Download completed. [Successful count = 693].
# Total time is 71.32090091705322 seconds.
# Reached end of page.
# Download completed. [Successful count = 915].
# Total time is 85.4826602935791 seconds.
# Reached end of page.
# Download completed. [Successful count = 954].
# Total time is 92.32802987098694 seconds.
# Reached end of page.
# Download completed. [Successful count = 0].
# Total time is 51.414435625076294 seconds.
# Reached end of page.
# Download completed. [Successful count = 724].
# Total time is 80.7849383354187 seconds.
# Reached end of page.
# Download completed. [Successful count = 818].
# Total time is 76.1243646144867 seconds.
# Reached end of page.
# Download completed. [Successful count = 941].
# Total time is 81.59990572929382 seconds.
# Reached end of page.
# Download completed. [Successful count = 879].
# Total time is 84.14773488044739 seconds.
# Reached end of page.
# Download completed. [Successful count = 863].
# Total time is 77.00302052497864 seconds.
# Reached end of page.
# Download completed. [Successful count = 774].
# Total time is 81.01731562614441 seconds.
# Reached end of page.
# Download completed. [Successful count = 821].
# Total time is 87.57382917404175 seconds.
# Reached end of page.
# Download completed. [Successful count = 728].
# Total time is 73.48443412780762 seconds.
# Reached end of page.
# Download completed. [Successful count = 859].
# Total time is 86.37096619606018 seconds.
# Reached end of page.
# Download completed. [Successful count = 846].
# Total time is 85.3666787147522 seconds.
# Reached end of page.
# Download completed. [Successful count = 829].
# Total time is 80.39611554145813 seconds.
# Reached end of page.
# Download completed. [Successful count = 901].
# Total time is 78.279611825943 seconds.
# Reached end of page.
# Download completed. [Successful count = 847].
# Total time is 116.16621613502502 seconds.
# Reached end of page.
# Download completed. [Successful count = 899].
# Total time is 78.97076106071472 seconds.
# Reached end of page.
# Download completed. [Successful count = 957].
# Total time is 78.30554342269897 seconds.
# Reached end of page.
# Download completed. [Successful count = 0].
# Total time is 56.049352407455444 seconds.
# Reached end of page.
# Download completed. [Successful count = 842].
# Total time is 84.62994647026062 seconds.
# Reached end of page.
# Download completed. [Successful count = 790].
# Total time is 81.3962664604187 seconds.
# Reached end of page.
# Download completed. [Successful count = 897].
# Total time is 96.0510401725769 seconds.
# Reached end of page.
# Download completed. [Successful count = 756].
# Total time is 85.36565327644348 seconds.
# Reached end of page.
# Download completed. [Successful count = 843].
# Total time is 83.17546486854553 seconds.
# Reached end of page.
# Download completed. [Successful count = 712].
# Total time is 72.36597084999084 seconds.
# Reached end of page.
# Download completed. [Successful count = 711].
# Total time is 84.72337460517883 seconds.
# Reached end of page.
# Download completed. [Successful count = 862].
# Total time is 95.17940068244934 seconds.
# Reached end of page.
# Download completed. [Successful count = 426].
# Total time is 76.62698769569397 seconds.
# Reached end of page.
# Download completed. [Successful count = 887].
# Total time is 102.21619915962219 seconds.
# Reached end of page.
# Download completed. [Successful count = 847].
# Total time is 91.7934205532074 seconds.
# Reached end of page.
# Download completed. [Successful count = 862].
# Total time is 107.00430035591125 seconds.
# Reached end of page.
# Download completed. [Successful count = 774].
# Total time is 133.7531774044037 seconds.
# Reached end of page.
# Download completed. [Successful count = 833].
# Total time is 90.42412209510803 seconds.
# Reached end of page.
# Download completed. [Successful count = 901].
# Total time is 93.78034615516663 seconds.
# Reached end of page.
# Download completed. [Successful count = 782].
# Total time is 81.93074941635132 seconds.
# Reached end of page.
# Download completed. [Successful count = 757].
# Total time is 154.95815253257751 seconds.
# Reached end of page.
# Download completed. [Successful count = 643].
# Total time is 80.473703622818 seconds.
# Reached end of page.
# Download completed. [Successful count = 890].
# Total time is 120.84825611114502 seconds.
# Reached end of page.
# Download completed. [Successful count = 843].
# Total time is 84.25264811515808 seconds.
# Reached end of page.
# Download completed. [Successful count = 736].
# Total time is 85.02556014060974 seconds.
# Reached end of page.
# Download completed. [Successful count = 577].
# Total time is 72.05625438690186 seconds.
# Reached end of page.
# Download completed. [Successful count = 920].
# Total time is 112.18690800666809 seconds.
# Reached end of page.
# Download completed. [Successful count = 787].
# Total time is 81.9388153553009 seconds.
# Reached end of page.
# Download completed. [Successful count = 2].
# Total time is 56.46699357032776 seconds.
# Reached end of page.
# Download completed. [Successful count = 843].
# Total time is 80.5046546459198 seconds.
# Reached end of page.
# Download completed. [Successful count = 681].
# Total time is 91.4743185043335 seconds.
# Reached end of page.
# Download completed. [Successful count = 792].
# Total time is 89.16548776626587 seconds.
# Reached end of page.
# Download completed. [Successful count = 0].
# Total time is 51.06938886642456 seconds.
# Reached end of page.
# Download completed. [Successful count = 874].
# Total time is 124.02523970603943 seconds.
# Reached end of page.
# Download completed. [Successful count = 679].
# Total time is 85.33473658561707 seconds.
# Reached end of page.
# Download completed. [Successful count = 802].
# Total time is 78.2257559299469 seconds.
# Reached end of page.
# Download completed. [Successful count = 863].
# Total time is 94.4344437122345 seconds.
# Reached end of page.
# Download completed. [Successful count = 755].
# Total time is 148.37399816513062 seconds.
# Reached end of page.
# Download completed. [Successful count = 863].
# Total time is 136.0796024799347 seconds.
# Reached end of page.
# Download completed. [Successful count = 928].
# Total time is 109.95761275291443 seconds.
# Reached end of page.
# Download completed. [Successful count = 564].
# Total time is 103.63177943229675 seconds.
# Reached end of page.
# Download completed. [Successful count = 911].
# Total time is 113.57120418548584 seconds.
# Reached end of page.
# Download completed. [Successful count = 875].
# Total time is 92.03281903266907 seconds.
# Reached end of page.
# Download completed. [Successful count = 921].
# Total time is 95.00187587738037 seconds.
# Reached end of page.
# Download completed. [Successful count = 695].
# Total time is 103.00067377090454 seconds.
# Reached end of page.
# Download completed. [Successful count = 801].
# Total time is 80.42486643791199 seconds.
# Reached end of page.
# Download completed. [Successful count = 777].
# Total time is 98.07465815544128 seconds.
# Reached end of page.
# Download completed. [Successful count = 886].
# Total time is 108.24499797821045 seconds.
# Reached end of page.
# Download completed. [Successful count = 694].
# Total time is 100.29771494865417 seconds.
# Reached end of page.
# Download completed. [Successful count = 722].
# Total time is 121.84956097602844 seconds.
# Reached end of page.
# Download completed. [Successful count = 773].
# Total time is 108.08687019348145 seconds.
# Reached end of page.
# Download completed. [Successful count = 783].
# Total time is 101.69429874420166 seconds.
# Reached end of page.
# Download completed. [Successful count = 415].
# Total time is 81.38915777206421 seconds.
# Reached end of page.
# Download completed. [Successful count = 707].
# Total time is 127.36338663101196 seconds.
# Reached end of page.
# Download completed. [Successful count = 787].
# Total time is 106.58987951278687 seconds.
# Reached end of page.
# Download completed. [Successful count = 759].
# Total time is 71.74009943008423 seconds.
# Reached end of page.
# Download completed. [Successful count = 53].
# Total time is 56.97658944129944 seconds.
# Reached end of page.
# Download completed. [Successful count = 741].
# Total time is 97.66159224510193 seconds.
# Reached end of page.
# Download completed. [Successful count = 829].
# Total time is 106.76540756225586 seconds.
# Reached end of page.
